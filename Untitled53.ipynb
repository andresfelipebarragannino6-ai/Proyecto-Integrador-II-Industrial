# %% [markdown]
# <a href="https://colab.research.google.com/github/andresfelipebarragannino6-ai/Proyecto-Integrador-II-Industrial/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import linregress

R = 8.314  # Constante universal de los gases J/(mol·K)
inv_t = 1 / (np.array([200, 220, 240]) + 273.15) # Temperaturas en Kelvin^-1

# Regresión lineal para k1 (Degradación)
slope1, intercept1, r_val1, _, _ = linregress(inv_t, np.log(k1_vals))

# Cálculo de parámetros físicos
ea_k1 = -slope1 * R / 1000  # Ea en kJ/mol
A_k1 = np.exp(intercept1)   # Factor pre-exponencial

print(f"Ea: {ea_k1:.2f} kJ/mol | R²: {r_val1**2:.3f}")
